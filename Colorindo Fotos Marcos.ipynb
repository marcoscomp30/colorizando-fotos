# %% [markdown]
# First Job in **Data Science**
#
# toc: false
#
# branch: master
#
# badges: false
#
# comments: True
#
# author: Marcos Felipe
#
# categories: [Buildings]

# %%
# !wget https://raw.githubusercontent.com/awarischool/br-data-science/master/image-colorizer/deoldify_wrapper.py
# Out:
# --2020-12-11 18:30:28--  https://raw.githubusercontent.com/awarischool/br-data-science/master/image-colorizer/deoldify_wrapper.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2623 (2.6K) [text/plain]
# Saving to: ‘deoldify_wrapper.py.6’
#
# deoldify_wrapper.py 100%[===================>]   2.56K  --.-KB/s    in 0s
#
# 2020-12-11 18:30:28 (50.5 MB/s) - ‘deoldify_wrapper.py.6’ saved [2623/2623]

# %%
from deoldify_wrapper import DeOldify
# Out:
#   File "/content/deoldify_wrapper.py", line 7
#     <!DOCTYPE html>
#     ^
# SyntaxError: invalid syntax
